# %% [markdown]
# # LIMPIEZA

# %%
#tratamiento de datos
import pandas as pd

#configuracion de visualizacion
pd.set_option('display.max_columns',None)

#exploracion de archivos
import sys
sys.path.append('../')

#funciones personalizadas
from SRC import sp_eda as se
from SRC import sp_limpieza as sl

# %%
df_u = pd.read_csv('../Datos/df_data_unificada.csv')

# %% [markdown]
# AJUSTE NOMBRE COLUMNAS

# %%
#Cambion de nombre de columnas (espacios y puntos por "_")
df_u.columns = df_u.columns.str.replace(' ', '_')
df_u.columns = df_u.columns.str.replace('.', '_')
df_u.columns = df_u.columns.str.lower()

# %%
df_u.columns
# Out:
# Index(['unnamed:_0_x', 'age', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx',
#        'cons_conf_idx', 'euribor3m', 'nr_employed', 'y', 'date', 'latitude',
#        'longitude', 'id_', 'unnamed:_0_y', 'income', 'kidhome', 'teenhome',
#        'dt_customer', 'numwebvisitsmonth', 'id'],
#       dtype='object')

# %% [markdown]
# ### LIMPIEZA

# %% [markdown]
# ELIMINACION DE COLUMNAS

# %%
df_u = df_u.drop(columns=['unnamed:_0_x', 'unnamed:_0_y', 'id_'])

# %% [markdown]
# AGE

# %%
#Conversion de float a Integer
df_u['age'] = df_u['age'].astype('Int64')

# %% [markdown]
# N.EMPLEADOS

# %%
#cambio "," por "." y conversion de Object a integer
df_u['nr_employed'] = df_u['nr_employed'].str.replace(',', '.').str.strip()
df_u['nr_employed'] = df_u['nr_employed'].astype(float).astype(int)

# %%
df_u['job'].unique()
# Out:
# array(['housemaid', 'services', 'admin.', 'blue-collar', 'technician',
#        'retired', 'management', 'unemployed', 'self-employed', nan,
#        'entrepreneur', 'student'], dtype=object)

# %% [markdown]
# JOB

# %%
# Cambio "-" por "_" y eliminacion de "." al final de admin
df_u['job'] = df_u['job'].str.replace('-', '_').str.strip('.')  # quitar espacios

# %% [markdown]
# FECHAS

# %%
df_u.sample(5)
# Out:
#         age            job  marital          education  default  housing  \
# 3523   <NA>        student   SINGLE                NaN      NaN      0.0
# 7334     37    blue_collar   SINGLE                NaN      NaN      0.0
# 1628     51    blue_collar  MARRIED           basic.9y      0.0      0.0
# 19335    30  self_employed   SINGLE  university.degree      0.0      1.0
# 26603    40     management  MARRIED                NaN      0.0      1.0
#
#        loan    contact  duration  campaign  pdays  previous     poutcome  \
# 3523    0.0  telephone       277         5    999         0  NONEXISTENT
# 7334    0.0  telephone       379         1    999         0  NONEXISTENT
# 1628    1.0  telephone       653         1    999         0  NONEXISTENT
# 19335   1.0   cellular       131         3    999         0  NONEXISTENT
# 26603   0.0   cellular       165         1    999         1      FAILURE
#
#        emp_var_rate cons_price_idx cons_conf_idx euribor3m  nr_employed    y  \
# 3523            1.1         93,994         -36,4     4,859         5191   no
# 7334            1.1         93,994         -36,4     4,864         5191   no
# 1628            1.1         93,994         -36,4     4,855         5191  yes
# 19335           1.4         93,444         -36,1       NaN         5228   no
# 26603          -0.1           93,2           -42       NaN         5195   no
#
#                      date  latitude  longitude  income  kidhome  teenhome  \
# 3523    23-noviembre-2019    43.261   -105.219   58281        2         2
# 7334          5-mayo-2015    45.629    -77.411  176239        0         2
# 1628    14-noviembre-2019    47.053    -91.203   30691        1         2
# 19335      21-agosto-2018    42.361    -73.082   22021        2         0
# 26603  15-septiembre-2017    32.927    -70.695   25254        2         1
#
#       dt_customer  numwebvisitsmonth                                    id
# 3523   2012-06-04                 16  2cfd1968-b21b-429a-89ed-97c7ec5aa902
# 7334   2012-12-21                 32  454bc370-5b56-4418-81bf-4a92099266bf
# 1628   2012-12-20                 10  5f459e39-e526-4097-af20-1a7e8038518b
# 19335  2012-03-27                 25  dac0e356-dd11-4928-87d9-f2cb6db48585
# 26603  2013-10-11                 10  85859955-f273-44e0-835f-f138f5bf32a5

# %%
meses = {
    'enero':'01', 'febrero':'02', 'marzo':'03', 'abril':'04',
    'mayo':'05', 'junio':'06', 'julio':'07', 'agosto':'08',
    'septiembre':'09', 'octubre':'10', 'noviembre':'11', 'diciembre':'12'
}

for mes_texto, mes_num in meses.items():
    df_u['date'] = df_u['date'].str.replace(mes_texto, mes_num)


for col in ['date', 'dt_customer']:
    df_u[col] = pd.to_datetime(df_u[col], dayfirst=True, errors='coerce')

# %%
cols = ['default', 'housing', 'loan']

for col in cols:

   df_u[col + '_str'] = df_u[col].astype(object).replace({0.0: 'No', 1.0: 'Yes'})

# %%
# al crear nuevas columnas categoricas a partir de las numericas procedemos a eliminar las numericas para dejar el df más despejado

df_u.drop(['default', 'housing', 'loan'], axis=1, inplace=True)

# %% [markdown]
# TODO EL DATA FRAME

# %% [markdown]
# conversion a minusculas,
# "." por "_",
# "," por ".",   e Integer por float

# %%
sl.minus(df_u)

# %%
sl.puntos(df_u)

# %%
sl.comas_float(df_u)

# %%
df_u = df_u.rename(columns={'y': 'subscription_prod','date':'date_contact' })

# %%
se.eda_preliminar(df_u)
# Out:
#        age          job  marital    education    contact  duration  campaign  \
# 2326    48        admin  married  high_school  telephone        82         1
# 33284   49      retired  married     basic_4y   cellular       179         1
# 32332   33  blue_collar  married  high_school   cellular       296         5
# 12621   35  blue_collar   single          NaN  telephone       564         1
# 7230    38  blue_collar  married  high_school  telephone       203         2
#
#        pdays  previous     poutcome  emp_var_rate  cons_price_idx  \
# 2326     999         0  nonexistent           1.1          93.994
# 33284    999         1      failure          -1.8          92.893
# 32332    999         1      failure          -1.8          92.893
# 12621    999         0  nonexistent           1.4          93.918
# 7230     999         0  nonexistent           1.1          93.994
#
#        cons_conf_idx  euribor3m  nr_employed subscription_prod date_contact  \
# 2326           -36.4      4.856         5191                no   2018-09-20
# 33284          -46.2      1.291         5099                no   2017-10-27
# 32332          -46.2      1.313         5099                no   2019-06-16
# 12621          -42.7      4.960         5228                no   2019-07-19
# 7230           -36.4        NaN         5191                no   2016-11-01
#
#        latitude  longitude  income  kidhome  teenhome dt_customer  \
# 2326     27.061    -98.809  149279        2         0  2012-09-01
# 33284    34.854    -67.810  114253        2         1  2014-05-01
# 32332    31.058    -67.754   89229        0         2         NaT
# 12621    28.206    -78.941   44164        1         2  2012-04-12
# 7230     42.504   -101.693    7471        0         2         NaT
#
#        numwebvisitsmonth                                    id default_str  \
# 2326                  30  a2c6a88f-9596-4f74-9206-497056fccac4          no
# 33284                  3  09b8bdde-3e8f-448a-baf9-7e464f3ae81a         NaN
# 32332                  8  cddef3f8-3668-4064-98e3-cdbfcec884bd         NaN
# 12621                 21  627186ed-f368-48dc-b9ef-b82189e1a65b          no
# 7230                  19  72df2511-ab56-4ad0-bf7d-7de67daac29a         NaN
#
#       housing_str loan_str
# 2326           no       no
# 33284          no       no
# 32332          no      yes
# 12621         yes       no
# 7230          yes       no
# ------------------------
# DIMENSIONES
# Nuestro conjunto de datos presenta un total de 43000 filas y 28 columnas
# ------------------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                37880 non-null  Int64
#  1   job                42655 non-null  object
#  2   marital            42915 non-null  object
#  3   education          41193 non-null  object
#  4   contact            43000 non-null  object
#  5   duration           43000 non-null  int64
#  6   campaign           43000 non-null  int64
#  7   pdays              43000 non-null  int64
#  8   previous           43000 non-null  int64
#  9   poutcome           43000 non-null  object
#  10  emp_var_rate       43000 non-null  float64
#  11  cons_price_idx     42529 non-null  float64
#  12  cons_conf_idx      43000 non-null  float64
#  13  euribor3m          33744 non-null  float64
#  14  nr_employed        43000 non-null  int64
#  15  subscription_prod  43000 non-null  object
#  16  date_contact       42752 non-null  datetime64[ns]
#  17  latitude           43000 non-null  float64
#  18  longitude          43000 non-null  float64
#  19  income             43000 non-null  int64
#  20  kidhome            43000 non-null  int64
#  21  teenhome           43000 non-null  int64
#  22  dt_customer        16867 non-null  datetime64[ns]
#  23  numwebvisitsmonth  43000 non-null  int64
#  24  id                 43000 non-null  object
#  25  default_str        34019 non-null  object
#  26  housing_str        41974 non-null  object
#  27  loan_str           41974 non-null  object
# dtypes: Int64(1), datetime64[ns](2), float64(6), int64(9), object(10)
# memory usage: 9.2+ MB
# None
# ------------------------
# NULOS
# age                  11.906977
# job                   0.802326
# marital               0.197674
# education             4.202326
# contact               0.000000
# duration              0.000000
# campaign              0.000000
# pdays                 0.000000
# previous              0.000000
# poutcome              0.000000
# emp_var_rate          0.000000
# cons_price_idx        1.095349
# cons_conf_idx         0.000000
# euribor3m            21.525581
# nr_employed           0.000000
# subscription_prod     0.000000
# date_contact          0.576744
# latitude              0.000000
# longitude             0.000000
# income                0.000000
# kidhome               0.000000
# teenhome              0.000000
# dt_customer          60.774419
# numwebvisitsmonth     0.000000
# id                    0.000000
# default_str          20.886047
# housing_str           2.386047
# loan_str              2.386047
# dtype: float64
# ------------------------
# DUPLICADOS
# 0
# ------------------------
# FRECUENCIA CATEGORICAS
# JOB
# job
# admin            10873
# blue_collar       9654
# technician        7026
# services          4162
# management        3050
# retired           1790
# entrepreneur      1522
# self_employed     1489
# housemaid         1123
# unemployed        1063
# student            903
# Name: count, dtype: int64
# ------------------------
# MARITAL
# marital
# married     25999
# single      12105
# divorced     4811
# Name: count, dtype: int64
# ------------------------
# EDUCATION
# education
# university_degree      12722
# high_school             9925
# basic_9y                6309
# professional_course     5477
# basic_4y                4356
# basic_6y                2386
# illiterate                18
# Name: count, dtype: int64
# ------------------------
# CONTACT
# contact
# cellular     27396
# telephone    15604
# Name: count, dtype: int64
# ------------------------
# POUTCOME
# poutcome
# nonexistent    37103
# failure         4461
# success         1436
# Name: count, dtype: int64
# ------------------------
# SUBSCRIPTION_PROD
# subscription_prod
# no     38156
# yes     4844
# Name: count, dtype: int64
# ------------------------
# ID
# id
# 089b39d8-e4d0-461b-87d4-814d71e0e079    1
# e9d37224-cb6f-4942-98d7-46672963d097    1
# 3f9f49b5-e410-4948-bf6e-f9244f04918b    1
# 9991fafb-4447-451a-8be2-b0df6098d13e    1
# eca60b76-70b6-4077-80ba-bc52e8ebb0eb    1
#                                        ..
# 4eed05de-2a98-4227-b488-32122009b638    1
# 0f0aca88-4088-4fe2-905f-44fb675d9493    1
# cadadd4b-7ee5-4019-b13a-ca01bb67ca5b    1
# 5f432048-d515-4bb5-9c94-62db451f88d4    1
# 993bbbd6-4dbc-4a40-a408-f91f8462bee6    1
# Name: count, Length: 43000, dtype: int64
# ------------------------
# DEFAULT_STR
# default_str
# no     34016
# yes        3
# Name: count, dtype: int64
# ------------------------
# HOUSING_STR
# housing_str
# yes    22498
# no     19476
# Name: count, dtype: int64
# ------------------------
# LOAN_STR
# loan_str
# no     35442
# yes     6532
# Name: count, dtype: int64
# ------------------------
# ------------------------
# ESTADISTICOS NUMERICAS
#                      count                           mean  \
# age                37880.0                      39.977112
# duration           43000.0                     257.739279
# campaign           43000.0                       2.567233
# pdays              43000.0                     962.330953
# previous           43000.0                       0.174023
# emp_var_rate       43000.0                       0.077128
# cons_price_idx     42529.0                      93.574219
# cons_conf_idx      43000.0                     -40.509049
# euribor3m          33744.0                       3.616521
# nr_employed        43000.0                     5166.66586
# date_contact         42752  2017-07-01 19:55:11.676646656
# latitude           43000.0                      36.856697
# longitude          43000.0                     -95.939067
# income             43000.0                    93241.20007
# kidhome            43000.0                       1.004791
# teenhome           43000.0                       0.998605
# dt_customer          16867  2013-05-05 06:21:21.887709952
# numwebvisitsmonth  43000.0                      16.589698
#
#                                    min                  25%  \
# age                               17.0                 32.0
# duration                           0.0                102.0
# campaign                           1.0                  1.0
# pdays                              0.0                999.0
# previous                           0.0                  0.0
# emp_var_rate                      -3.4                 -1.8
# cons_price_idx                  92.201               93.075
# cons_conf_idx                    -50.8                -42.7
# euribor3m                        0.634                1.344
# nr_employed                     4963.0               5099.0
# date_contact       2015-01-01 00:00:00  2016-04-01 00:00:00
# latitude                        24.396             30.61475
# longitude                     -124.997           -110.49425
# income                          5841.0              49610.0
# kidhome                            0.0                  0.0
# teenhome                           0.0                  0.0
# dt_customer        2012-01-01 00:00:00  2012-07-07 00:00:00
# numwebvisitsmonth                  1.0                  9.0
#
#                                    50%                  75%  \
# age                               38.0                 47.0
# duration                         179.0                319.0
# campaign                           2.0                  3.0
# pdays                            999.0                999.0
# previous                           0.0                  0.0
# emp_var_rate                       1.1                  1.4
# cons_price_idx                  93.749               93.994
# cons_conf_idx                    -41.8                -36.4
# euribor3m                        4.857                4.961
# nr_employed                     5191.0               5228.0
# date_contact       2017-07-04 00:00:00  2018-10-01 06:00:00
# latitude                        36.761             43.11325
# longitude                     -95.8995            -81.42775
# income                         93050.5             136744.5
# kidhome                            1.0                  2.0
# teenhome                           1.0                  2.0
# dt_customer        2013-03-01 00:00:00  2014-03-11 00:00:00
# numwebvisitsmonth                 17.0                 25.0
#
#                                    max           std
# age                               98.0     10.437957
# duration                        4918.0    258.666033
# campaign                          56.0      2.772294
# pdays                            999.0    187.260394
# previous                           7.0      0.497366
# emp_var_rate                       1.4      1.573898
# cons_price_idx                  94.767      0.579548
# cons_conf_idx                    -26.9      4.637186
# euribor3m                        5.045      1.737117
# nr_employed                     5228.0     72.488304
# date_contact       2019-12-31 00:00:00           NaN
# latitude                        49.384      7.225948
# longitude                      -66.937     16.752282
# income                        180802.0  50498.316182
# kidhome                            2.0      0.815913
# teenhome                           2.0      0.815983
# dt_customer        2014-12-12 00:00:00           NaN
# numwebvisitsmonth                 32.0      9.239205

# %%
df_u.to_csv('../Datos/df_data_limpios.csv', index=False)
