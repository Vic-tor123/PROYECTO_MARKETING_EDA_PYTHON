# %%
import pandas as pd

pd.set_option('display.max_columns',None)

# %%
df_c = pd.read_csv('../Datos.Originales/bank-additional.csv')
df_e = pd.read_excel('../Datos.Originales/customer-details.xlsx')

# %%
df_e.sample(5)
# Out:
#        Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 4610         4610   63572        2         1  2012-04-12                  8
# 3450         3450  115275        1         1  2012-09-21                 25
# 9993         9993    8084        2         0  2012-10-29                 30
# 11170       11170   48815        1         2  2012-02-26                 27
# 1635         1635   14255        0         0  2012-11-18                  2
#
#                                          ID
# 4610   d94b0aaf-bc52-412b-b675-56ab425f2212
# 3450   96582df4-31ea-4180-bb7a-550645e65866
# 9993   1e9ea17a-623a-422b-b930-46944a6bf77e
# 11170  21cb4d63-29d1-4250-9693-3bf07fba4b3a
# 1635   15d3d538-4288-4313-b8d2-4a7a4000c2cd

# %%
df
